# %%
input_vars = {
"userId": 484132203, "applicationId": 2303527, "flowTime": "2026-03-01 12:00:02.0",
"bank_accounts": [{"bank_account_id": 4429596, "account_type": ""}, {"bank_account_id": "4429597", "account_type": ""}, {"bank_account_id": "4429596", "account_type": ""}], 
"illion_raw_transactions": [{"amount": 155.08, "balance": 591.41, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "4d511597-8542-4257-b7f9-436f1dd1d570", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4wfpel 26840439", "third_party": "Moneyspot", "transaction_date": "2025-12-23", "transaction_id": 2604737994, "trx_type": "General Payment"}, {"amount": 271.17, "balance": 787.43, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "41c9ca3a-cf0d-4877-afdc-e096fb21af1a", "text": "PAYMENT BY AUTHORITY TO MoneySpot DT.51sn8u 27325040", "third_party": "Moneyspot", "transaction_date": "2026-02-03", "transaction_id": 2604737891, "trx_type": "General Payment"}, {"amount": 236.25, "balance": 854.79, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "00b1170d-32d4-472a-bed1-6c3d784d1499", "text": "PAYMENT BY AUTHORITY TO Beforepay 026630 DT.4zxwwn GV176556", "third_party": "Beforepay", "transaction_date": "2026-01-20", "transaction_id": 2604737945, "trx_type": "General Payment"}, {"amount": 10.0, "balance": 1387.51, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "14ecff69-394d-446b-9ca9-a532320037b4", "text": "WITHDRAWAL-OSKO PAYMENT 1957734 DONALD CRAIGIE", "third_party": "Osko", "transaction_date": "2025-09-03", "transaction_id": 2604738461, "trx_type": "General Payment"}, {"amount": 120.0, "balance": 362.22, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "d00bb285-b228-4840-aa27-4ce7e4c92fcd", "text": "DEBIT CARD PURCHASE ZipPay P781109099 Sydney AUS", "third_party": "Zip Pay", "transaction_date": "2025-09-04", "transaction_id": 2604738451, "trx_type": ""}, {"amount": 24.82, "balance": 798.18, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "8ed8933f-aff1-424d-96b0-72c59628b4dc", "text": "DEBIT CARD PURCHASE SPORTSBET MELBOURNE AUS", "third_party": "Sportsbet", "transaction_date": "2025-12-15", "transaction_id": 2604738043, "trx_type": ""}, {"amount": 20.0, "balance": 523.96, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "c81f6d33-8016-4afe-81fa-5a4e5900a103", "text": "DEBIT CARD PURCHASE COFFS HARBOUR Top Toba Coffs Harbou AUS", "third_party": "", "transaction_date": "2026-01-27", "transaction_id": 2604737919, "trx_type": ""}, {"amount": 350.0, "balance": 980.74, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "72aefc5c-e8b0-434c-8b08-b00dee4646d5", "text": "WITHDRAWAL-OSKO PAYMENT 1010188 M RADFORD", "third_party": "Osko", "transaction_date": "2026-02-18", "transaction_id": 2604737847, "trx_type": "General Payment"}, {"amount": 155.08, "balance": 709.62, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "035b54f4-8e4d-4249-8d2a-1aee99fd2aa8", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4y46cp 26840440", "third_party": "Moneyspot", "transaction_date": "2026-01-06", "transaction_id": 2604737972, "trx_type": "General Payment"}, {"amount": 148.39, "balance": 22.72, "bank_account_id": 4429596, "category": "Dishonours", "dr_cr": "credit", "illion_trx_uuid": "940e296a-c03b-4df3-9112-b672468e6d84", "text": "DIRECT DEBIT DISHONOURED 0600996", "third_party": "", "transaction_date": "2026-02-02", "transaction_id": 2604737899, "trx_type": "Direct Debit Reversal"}, {"amount": 25.42, "balance": 242.5, "bank_account_id": 4429596, "category": "Automotive", "dr_cr": "debit", "illion_trx_uuid": "b672e458-4c77-4bfb-b326-9526917300eb", "text": "DEBIT CARD PURCHASE BP BOAMBEE 7319 BOAMBEE AUS", "third_party": "BP Stations", "transaction_date": "2025-09-29", "transaction_id": 2604738359, "trx_type": ""}, {"amount": 20.0, "balance": 1099.53, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "ea5f3781-c9b9-474b-81aa-7493ff64ffcb", "text": "DEBIT CARD PURCHASE KENJO NAYIF KAMAL HAM Coffs Harbou AUS", "third_party": "", "transaction_date": "2025-10-30", "transaction_id": 2604738235, "trx_type": ""}, {"amount": 21.26, "balance": 1029.73, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "0ca3b2de-c0ca-4c50-8546-04c96bafcd9a", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2025-12-23", "transaction_id": 2604737997, "trx_type": ""}, {"amount": 2.9, "balance": 575.45, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "e966072f-bc0c-404a-8dbb-1a6754c0be50", "text": "ATM OPERATOR FEE - WITHDRAWAL AT ETX ATM COFFS HAR 00002549057851 261125", "third_party": "", "transaction_date": "2025-11-26", "transaction_id": 2604738120, "trx_type": "ATM Fees"}, {"amount": 22.0, "balance": 119.56, "bank_account_id": 4429596, "category": "Groceries", "dr_cr": "debit", "illion_trx_uuid": "38c6d736-1d55-486d-877a-ea94134b3b66", "text": "DEBIT CARD PURCHASE RITCHIES BOAMBEE BOAMBEE EAST AUS", "third_party": "Ritchies", "transaction_date": "2026-01-28", "transaction_id": 2604737911, "trx_type": ""}, {"amount": 1825.35, "balance": 1826.91, "bank_account_id": 4429596, "category": "Wages", "dr_cr": "credit", "illion_trx_uuid": "2f671e4a-209b-4f5c-a835-93a8ab29fea3", "text": "DEPOSIT-SALARY Enterprise & Tra WAGES", "third_party": "Enterprise & Tra", "transaction_date": "2026-02-17", "transaction_id": 2604737861, "trx_type": "Wage Payments 2"}, {"amount": 78.45, "balance": 34.84, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "a2ccdd62-2e57-40d6-b064-a6d5de268598", "text": "DEBIT CARD PURCHASE JUN & T PTY LTD COFFS HARBOU AUS", "third_party": "Dining Out", "transaction_date": "2025-10-21", "transaction_id": 2604738255, "trx_type": ""}, {"amount": 2.9, "balance": 53.92, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "bf448006-86fd-40f8-9492-1ae87db3c096", "text": "ATM OPERATOR FEE - WITHDRAWAL AT ETX ATM COFFS HAR 00002549064695 041125", "third_party": "", "transaction_date": "2025-11-04", "transaction_id": 2604738203, "trx_type": "ATM Fees"}, {"amount": 2.9, "balance": 227.71, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "49fc7b22-8170-4664-87f7-f8cf6a933665", "text": "ATM OPERATOR FEE - WITHDRAWAL AT ETX ATM COFFS HAR 00021018062809 060925", "third_party": "", "transaction_date": "2025-09-08", "transaction_id": 2604738421, "trx_type": "ATM Fees"}, {"amount": 30.0, "balance": 4442.19, "bank_account_id": 4429596, "category": "Groceries", "dr_cr": "debit", "illion_trx_uuid": "b1735e77-dd26-4b8b-b638-60719279a7c1", "text": "DEBIT CARD PURCHASE RITCHIES BOAMBEE BOAMBEE EAST AUS", "third_party": "Ritchies", "transaction_date": "2025-12-22", "transaction_id": 2604738014, "trx_type": ""}, {"amount": 13.14, "balance": 236.82, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "20dabb26-3399-4e31-9e44-976a64797f8f", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2025-11-04", "transaction_id": 2604738209, "trx_type": ""}, {"amount": 150.0, "balance": 191.56, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "a058f3b4-d5ba-4a34-a654-ea24a50330fa", "text": "WITHDRAWAL-OSKO PAYMENT 1087143 IAN PERRY 25 JAN 2026", "third_party": "Osko", "transaction_date": "2026-01-27", "transaction_id": 2604737913, "trx_type": "General Payment"}, {"amount": 15.35, "balance": 210.73, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "0a2f7679-6670-427b-aa69-8df87ca1d618", "text": "DEBIT CARD PURCHASE Hungry Jacks Coffs Harbou AUS", "third_party": "Hungry Jack's", "transaction_date": "2025-10-10", "transaction_id": 2604738312, "trx_type": ""}, {"amount": 22.0, "balance": 5.57, "bank_account_id": 4429596, "category": "Groceries", "dr_cr": "debit", "illion_trx_uuid": "53b6419b-61be-471b-b942-631f78339bcc", "text": "DEBIT CARD PURCHASE RITCHIES BOAMBEE BOAMBEE EAST AUS", "third_party": "Ritchies", "transaction_date": "2025-11-20", "transaction_id": 2604738144, "trx_type": ""}, {"amount": 40.0, "balance": 37.58, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "f2509797-6cb6-45f6-a79a-36f070a2d935", "text": "WITHDRAWAL AT ETX ATM COFFS HAR 00081255065920 280925", "third_party": "", "transaction_date": "2025-09-29", "transaction_id": 2604738354, "trx_type": "ATM Withdrawals"}, {"amount": 343.11, "balance": 744.35, "bank_account_id": 4429596, "category": "SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "de186563-3bdc-45c3-959d-f48f093861e1", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4lbd2l 24753275", "third_party": "Moneyspot", "transaction_date": "2025-09-30", "transaction_id": 2604738343, "trx_type": "General Payment"}, {"amount": 5.0, "balance": 139.76, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "03a03a0c-fdce-42b5-a456-562893851166", "text": "DEBIT CARD PURCHASE SPORTSBET MELBOURNE AUS", "third_party": "Sportsbet", "transaction_date": "2025-12-08", "transaction_id": 2604738084, "trx_type": ""}, {"amount": 33.24, "balance": 709.94, "bank_account_id": 4429596, "category": "Groceries", "dr_cr": "debit", "illion_trx_uuid": "03338459-99dd-4009-a84f-33411595ee1e", "text": "DEBIT CARD PURCHASE RITCHIES BOAMBEE BOAMBEE EAST AUS", "third_party": "Ritchies", "transaction_date": "2025-12-15", "transaction_id": 2604738040, "trx_type": ""}, {"amount": 8.87, "balance": 4579.01, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "dd4cc087-2330-45b0-95da-5ed0b4b8d5e4", "text": "DEBIT CARD PURCHASE COAST HOTEL L0469 COFFS HARBOU AUS", "third_party": "Hotels and Pubs", "transaction_date": "2025-12-22", "transaction_id": 2604738020, "trx_type": ""}, {"amount": 120.0, "balance": 104.79, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "0c0802fb-6c83-489e-b473-b64cf687ed08", "text": "DEBIT CARD PURCHASE ZipPay P786636465 Sydney AUS", "third_party": "Zip Pay", "transaction_date": "2025-09-18", "transaction_id": 2604738371, "trx_type": ""}, {"amount": 330.0, "balance": 408.98, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "2058b315-789c-4f91-b970-b52e079a5c0b", "text": "WITHDRAWAL-OSKO PAYMENT 1003301 M RADFORD", "third_party": "Osko", "transaction_date": "2025-10-06", "transaction_id": 2604738317, "trx_type": "General Payment"}, {"amount": 7.08, "balance": 1121.89, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "8ae55f05-ac4c-41e6-8c1a-b05af0cf81bf", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2025-10-15", "transaction_id": 2604738280, "trx_type": ""}, {"amount": 343.11, "balance": 941.18, "bank_account_id": 4429596, "category": "SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "dc161b2f-9f52-465a-a512-a1a39152603a", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4jid1g 24753274", "third_party": "Moneyspot", "transaction_date": "2025-09-16", "transaction_id": 2604738388, "trx_type": "General Payment"}, {"amount": 35.1, "balance": 1064.8, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "d89cb97a-979d-4dd5-86f6-404600af3885", "text": "DEBIT CARD PURCHASE Hungry Jacks Campbelltown AUS", "third_party": "Hungry Jack's", "transaction_date": "2026-01-07", "transaction_id": 2604737968, "trx_type": ""}, {"amount": 40.0, "balance": 8.88, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "f9a806b1-8966-47e6-aa92-fe865b7355ea", "text": "WITHDRAWAL AT ETX ATM COFFS HAR 00021018084098 031025", "third_party": "", "transaction_date": "2025-10-03", "transaction_id": 2604738324, "trx_type": "ATM Withdrawals"}, {"amount": 16.5, "balance": 589.21, "bank_account_id": 4429596, "category": "Groceries", "dr_cr": "debit", "illion_trx_uuid": "8d906618-5092-489c-a3d1-b8cdb6ba21cc", "text": "DEBIT CARD PURCHASE BRAY ST SUPERMARKETS COFFS HARBOU AUS", "third_party": "Miscellaneous Grocery stores", "transaction_date": "2025-09-04", "transaction_id": 2604738455, "trx_type": ""}, {"amount": 60.0, "balance": 287.22, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "6c03cbae-4c18-4e3a-bf6c-22aedd237b7e", "text": "WITHDRAWAL AT ETX ATM COFFS HAR 00021018078307 040925", "third_party": "", "transaction_date": "2025-09-04", "transaction_id": 2604738449, "trx_type": "ATM Withdrawals"}, {"amount": 5.0, "balance": 351.44, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "7bf4e2eb-578d-4456-9a3f-3d98a604c4c5", "text": "DEBIT CARD PURCHASE SPORTSBET PTY LTD Melbourne AUS", "third_party": "Sportsbet", "transaction_date": "2025-10-13", "transaction_id": 2604738307, "trx_type": ""}, {"amount": 100.0, "balance": 76.82, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "5a1680e2-abc4-45c6-ba0c-743ee6cffdf1", "text": "DEBIT CARD PURCHASE SPORTSBET PTY LTD Melbourne AUS", "third_party": "Sportsbet", "transaction_date": "2025-11-04", "transaction_id": 2604738205, "trx_type": ""}, {"amount": 2.9, "balance": 372.99, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "e75bdd5d-0be2-4af3-9ba0-b83119cc3ca3", "text": "ATM OPERATOR FEE - WITHDRAWAL AT ETX ATM COFFS HAR 00081255064204 091225", "third_party": "", "transaction_date": "2025-12-09", "transaction_id": 2604738065, "trx_type": "ATM Fees"}, {"amount": 72.0, "balance": 746.49, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "5fbdccde-9dc3-4a8f-a198-207123536877", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4wfpcx 26840448", "third_party": "Moneyspot", "transaction_date": "2025-12-23", "transaction_id": 2604737995, "trx_type": "General Payment"}, {"amount": 5.0, "balance": 1.88, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "192b7f91-5170-4029-839a-bf46164c1d04", "text": "WITHDRAWAL-OSKO PAYMENT 1311926 Jeena Gineesh", "third_party": "Osko", "transaction_date": "2025-12-04", "transaction_id": 2604738092, "trx_type": "General Payment"}, {"amount": 1825.35, "balance": 1828.08, "bank_account_id": 4429596, "category": "Wages", "dr_cr": "credit", "illion_trx_uuid": "f059eed8-fb5a-4464-a6ec-a54d73a6f6f5", "text": "DEPOSIT-SALARY Enterprise & Tra WAGES", "third_party": "Enterprise & Tra", "transaction_date": "2025-11-11", "transaction_id": 2604738189, "trx_type": "Wage Payments 2"}, {"amount": 100.0, "balance": 657.04, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "credit", "illion_trx_uuid": "3eae54f6-edc6-4d05-b963-70a53f1ce03c", "text": "DEPOSIT 2282806 MyPayNow Advance CT.1ktde5 MyPayNow Advance CT.1ktde5", "third_party": "MyPayNow", "transaction_date": "2025-11-17", "transaction_id": 2604738165, "trx_type": "Inbound Transfer"}, {"amount": 300.0, "balance": 375.89, "bank_account_id": 4429596, "category": "", "dr_cr": "debit", "illion_trx_uuid": "6163e454-e05f-420c-b000-ad6c9936509f", "text": "WITHDRAWAL AT ETX ATM COFFS HAR 00081255064204 091225", "third_party": "", "transaction_date": "2025-12-09", "transaction_id": 2604738066, "trx_type": "ATM Withdrawals"}, {"amount": 148.39, "balance": 17.56, "bank_account_id": 4429596, "category": "Dishonours", "dr_cr": "credit", "illion_trx_uuid": "7e412caa-d3df-49b0-891a-5d7db1b68029", "text": "DIRECT DEBIT DISHONOURED 0600996", "third_party": "", "transaction_date": "2026-02-16", "transaction_id": 2604737863, "trx_type": "Direct Debit Reversal"}, {"amount": 20.0, "balance": 580.14, "bank_account_id": 4429596, "category": "External Transfers", "dr_cr": "debit", "illion_trx_uuid": "45e05251-6f7e-4592-bb87-46a1b7563158", "text": "WITHDRAWAL-OSKO PAYMENT 1286316 B SALES", "third_party": "Osko", "transaction_date": "2025-11-17", "transaction_id": 2604738152, "trx_type": "General Payment"}, {"amount": 60.0, "balance": 60.08, "bank_account_id": 4429596, "category": "Retail", "dr_cr": "debit", "illion_trx_uuid": "335fe555-a001-465f-961d-31f35df07c9d", "text": "DEBIT CARD PURCHASE HARVEY NORMAN AV/IT COFFS HARBOU AUS", "third_party": "Furniture and Appliances", "transaction_date": "2025-12-01", "transaction_id": 2604738095, "trx_type": ""}, {"amount": 28.19, "balance": 11.67, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "ff267a03-89b7-42ca-9253-380ef2a84ee1", "text": "DEBIT CARD PURCHASE CAMPBELLTOWN CLUB CAMPBELLTOWN AUS", "third_party": "Dining Out", "transaction_date": "2026-01-08", "transaction_id": 2604737959, "trx_type": ""}, {"amount": 2.9, "balance": 1068.52, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "0cb2bea6-4208-4446-9936-0e17e96d4466", "text": "ATM OPERATOR FEE - WITHDRAWAL AT ETX ATM COFFS HAR 00021018068969 221225", "third_party": "", "transaction_date": "2025-12-22", "transaction_id": 2604738000, "trx_type": "ATM Fees"}, {"amount": 0.68, "balance": 0.08, "bank_account_id": 4429596, "category": "Fees", "dr_cr": "debit", "illion_trx_uuid": "446ba4a0-6278-43fa-8caf-a2cdca8e0a52", "text": "INTEREST", "third_party": "", "transaction_date": "2026-02-27", "transaction_id": 2604737833, "trx_type": "Interest Charge"}, {"amount": 32.02, "balance": 106.06, "bank_account_id": 4429596, "category": "Automotive", "dr_cr": "debit", "illion_trx_uuid": "48b2fca3-113a-4406-9021-8ec39f41cfc5", "text": "DEBIT CARD PURCHASE BP COFFS HARBOUR 1124 COFFS HARBOU AUS", "third_party": "BP Stations", "transaction_date": "2025-11-24", "transaction_id": 2604738139, "trx_type": ""}, {"amount": 148.39, "balance": -294.42, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "08c4835a-fc57-4e78-b149-96b7ea4ed74e", "text": "PAYMENT BY AUTHORITY TO QuickCash DT.4ziseo 27371327", "third_party": "Moneyspot", "transaction_date": "2026-01-16", "transaction_id": 2604737954, "trx_type": "General Payment"}, {"amount": 35.0, "balance": 441.56, "bank_account_id": 4429596, "category": "Telecommunications", "dr_cr": "debit", "illion_trx_uuid": "933e152c-45cc-4c88-8aa3-b902e571c2b6", "text": "DEBIT CARD PURCHASE Belong Melbourne AUS", "third_party": "BELONG", "transaction_date": "2026-01-27", "transaction_id": 2604737916, "trx_type": ""}, {"amount": 7.09, "balance": 22.72, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "81207e67-d5e0-45f6-8f45-31e9fa4ce54b", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2026-01-30", "transaction_id": 2604737903, "trx_type": ""}, {"amount": 7.08, "balance": 266.99, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "409ba278-8232-454a-927f-08308224a413", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2025-09-05", "transaction_id": 2604738445, "trx_type": ""}, {"amount": 50.0, "balance": 341.56, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "43fafa79-910e-4353-b713-476f525a6f10", "text": "DEBIT CARD PURCHASE SPORTSBET MELBOURNE AUS", "third_party": "Sportsbet", "transaction_date": "2026-01-27", "transaction_id": 2604737914, "trx_type": ""}, {"amount": 35.0, "balance": 2.36, "bank_account_id": 4429596, "category": "Telecommunications", "dr_cr": "debit", "illion_trx_uuid": "028a4df7-6309-4e71-8e39-0089647fa56a", "text": "DEBIT CARD PURCHASE Belong Melbourne AUS", "third_party": "BELONG", "transaction_date": "2026-01-13", "transaction_id": 2604737956, "trx_type": ""}, {"amount": 120.0, "balance": 894.42, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "2519d133-46f0-40d8-a3bb-d79797819cd5", "text": "DEBIT CARD PURCHASE ZIPPAY* P829574806 SYDNEY AUS", "third_party": "Zip Pay", "transaction_date": "2026-01-07", "transaction_id": 2604737966, "trx_type": ""}, {"amount": 157.91, "balance": 1180.61, "bank_account_id": 4429596, "category": "Retail", "dr_cr": "debit", "illion_trx_uuid": "a0026e57-b767-4207-9c6c-3e6bff6530a5", "text": "DEBIT CARD PURCHASE Outdoor Supacentre Coffs Harbou AUS", "third_party": "Retail", "transaction_date": "2025-09-08", "transaction_id": 2604738427, "trx_type": ""}, {"amount": 313.56, "balance": -1.08, "bank_account_id": 4429596, "category": "Non SACC Loans", "dr_cr": "debit", "illion_trx_uuid": "d9fa48ba-771e-4365-b82a-13a9baad3843", "text": "PAYMENT BY AUTHORITY TO AUDI 00810296", "third_party": "Audi Finance", "transaction_date": "2026-01-21", "transaction_id": 2604737933, "trx_type": "General Payment"}, {"amount": 7.08, "balance": 174.78, "bank_account_id": 4429596, "category": "Dining Out", "dr_cr": "debit", "illion_trx_uuid": "1f1f535d-3aaa-4a07-b4e6-ac5529053e1f", "text": "DEBIT CARD PURCHASE DARK ARTS CAFE & BAR COFFS HARBOU AUS", "third_party": "Miscellaneous Cafes", "transaction_date": "2025-11-06", "transaction_id": 2604738199, "trx_type": ""}, {"amount": 10.0, "balance": 124.76, "bank_account_id": 4429596, "category": "Gambling", "dr_cr": "debit", "illion_trx_uuid": "d58aab52-1f03-4f26-859c-3446643aed07", "text": "DEBIT CARD PURCHASE SPORTSBET MELBOURNE AUS", "third_party": "Sportsbet", "transaction_date": "2025-12-08", "transaction_id": 2604738082, "trx_type": ""}],

      "illion_day_end_balances": [
    {
      "balance": -42560.72,
      "balance_date": "2025-09-28",
      "balance_id": "1.07723905e+09",
      "bank_account_id": "3948332"
    },
    {
      "balance": -42144.71,
      "balance_date": "2025-09-27",
      "balance_id": "1.077239051e+09",
      "bank_account_id": "3948332"
    }
  ]
}

# %%
input_vars = {
    "userId": 483954710,
    "applicationId": 2303374,
    "flowTime": "2026-02-01 00:43:12.0",

    "bank_accounts": [
        {
            "bank_account_id": "4429194",
            "account_type": ""
        }
    ],

    "illion_raw_transactions": [
        {
            "amount": 300,
            "balance": 972.83,
            "bank_account_id": "4429194",
            "category": "Fees",
            "dr_cr": "debit",
            "illion_trx_uuid": "0c1a2246-db3d-4828-8710-47fa5987a5c3",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-12-04",
            "transaction_id": "2604483436",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 10,
            "balance": 48.87,
            "bank_account_id": "4429194",
            "category": "Fees",
            "dr_cr": "debit",
            "illion_trx_uuid": "091130e6-74a0-4b7a-a276-4ecb83136978",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-11-11",
            "transaction_id": "2604483493",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 44,
            "balance": 84.88,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "credit",
            "illion_trx_uuid": "3f79577f-9f7f-4aff-ae33-d3ba5bc99ee7",
            "text": "Transfer from xx2132 CommBank app",
            "third_party": "Internal Transfer Credit",
            "transaction_date": "2025-10-22",
            "transaction_id": "2604483553",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 30,
            "balance": 126.41,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "debit",
            "illion_trx_uuid": "f67f9c04-c626-40fc-8283-d015669177cf",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-12-17",
            "transaction_id": "2604483391",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 200,
            "balance": 2094.43,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "debit",
            "illion_trx_uuid": "c2dc55b6-62e9-47ab-b948-a858f6385164",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-09-05",
            "transaction_id": "2604483729",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 0.16,
            "balance": 0.16,
            "bank_account_id": "4429194",
            "category": "All Other Credits",
            "dr_cr": "credit",
            "illion_trx_uuid": "338008a4-1b79-4917-9d49-ead9b312256d",
            "text": "Credit Interest",
            "third_party": "Other Credits",
            "transaction_date": "2026-02-01",
            "transaction_id": "2604483319",
            "trx_type": "Earned Interest"
        },
        {
            "amount": 6,
            "balance": 13.59,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "debit",
            "illion_trx_uuid": "7da23f59-93d7-4d92-ad88-100328d90bb1",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-10-09",
            "transaction_id": "2604483596",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 45,
            "balance": 336.15,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "debit",
            "illion_trx_uuid": "65fa34d9-b6b9-4ef5-bd82-ef9fe21466bb",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-12-21",
            "transaction_id": "2604483379",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 247.29,
            "balance": 469.52,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "credit",
            "illion_trx_uuid": "f8047a9c-76dc-4ed1-a30b-084fb55b2a4f",
            "text": "Transfer from xx2132 CommBank app",
            "third_party": "Internal Transfer Credit",
            "transaction_date": "2025-11-16",
            "transaction_id": "2604483474",
            "trx_type": "Internal Transfer"
        },
        {
            "amount": 22.3,
            "balance": 0,
            "bank_account_id": "4429194",
            "category": "Internal Transfer",
            "dr_cr": "debit",
            "illion_trx_uuid": "b763e5f1-a45f-4b3a-95db-ad99a84ee535",
            "text": "Transfer to xx2132 CommBank app",
            "third_party": "Internal Transfer Debit",
            "transaction_date": "2025-11-12",
            "transaction_id": "2604483487",
            "trx_type": "Internal Transfer"
        }
    ],

      "illion_day_end_balances": [
    {
      "balance": -42560.72,
      "balance_date": "2025-09-28",
      "balance_id": "1.07723905e+09",
      "bank_account_id": "3948332"
    },
    {
      "balance": -42144.71,
      "balance_date": "2025-09-27",
      "balance_id": "1.077239051e+09",
      "bank_account_id": "3948332"
    }
  ]
}

# %% [markdown]
# # 特征回溯测试

# %%
import json
import time
from datetime import datetime

from v1_0_20251201.run_model_feature import (generate_score,run_model_feature)

print("========== run_model_feature ==========")

# ===== 开始时间 =====
start_time = time.time()
print("Start Time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

res_feature = run_model_feature(input_vars, dict_csv_path="./dict.csv")

# ===== 结束时间 =====
end_time = time.time()
print("End Time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# ===== 总耗时 =====
print(f"Total Time: {end_time - start_time:.2f} seconds")
# Out:
# ========== run_model_feature ==========
# Start Time: 2026-03-20 02:40:52
# End Time: 2026-03-20 02:41:02
# Total Time: 9.41 seconds

# %% [markdown]
# # 模型分回溯测试

# %%
import json
import time
from datetime import datetime
import numpy as np

from v1_0_20260327.run_model import (generate_score)


print("========== run_model_feature ==========")

# ===== 开始时间 =====
start_time = time.time()
print("Start Time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

res = generate_score(input_vars)

# ===== 结束时间 =====
end_time = time.time()
print("End Time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# ===== 总耗时 =====
print(f"Total Time: {end_time - start_time:.2f} seconds")

res
# Out:
# ========== run_model_feature ==========
# Start Time: 2026-03-27 09:30:32
# End Time: 2026-03-27 09:30:36
# Total Time: 3.33 seconds
# {'aus_old_risk_bid_submodel_20260323_v1_2_txn_lgb': 0.04101206412286587,
#  'aus_old_risk_bid_submodel_20260323_v1_2_txn_lgb_features': {'balance_date_max': '2025-09-28',
#   'bank_txn_balance_debit_gap_max_182d': -999999.99999,
#   'bank_txn_balance_kurtosis_182d': -999999.99999,
#   'bank_txn_balance_skewness_182d': -999999.99999,
#   'bank_txn_balance_std_168d': 294.16349,
#   'bank_txn_category_cluster_debt_share_182d': 0.51559,
#   'bank_txn_category_dishonours_credit_cnt_56d': 2,
#   'bank_txn_category_external_transfers_share_28d': 0.56284,
#   'bank_txn_category_internal_transfer_credit_amt_182d': 0.0,
#   'bank_txn_category_non_sacc_loans_debit_cnt_28d': 1,
#   'bank_txn_expense_insurance_ratio_14d': 0,
#   'bank_txn_expense_internaltransfer_daily_max_14d': -999999.99999,
# ...
